# %% [markdown]
# # Livro - Introdução à Algoritmos e Programação com PYTHON

# %% [markdown]
# # Capítulo 2 - Alô Mundo!

# %%
print('Alô Mundo!')
# Out:
# Alô Mundo!

# %%
print("Alô Mundo!')
# Out:
#   File "<ipython-input-3-bd582db710d5>", line 1
#     print("Alô Mundo!')
#                        ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# EOL= End of line (Final da linha encontrado enquanto analisava uma literal).

# %%
print('Alô Mundo!')
# Out:
# Alô Mundo!

# %%
print('Alô Mundo!')
print('Bom dia!')
# Out:
# Alô Mundo!
# Bom dia!

# %% [markdown]
# Cada vez que você utiliza a função print ele acrescenta um caractere invisível ao final da impressãoque é conhecido como "quebra de linha". Esse caractere faz com que a próxima coisa impressa na tela apareça na linha seguinte e não ao lado da última imptrssão.

# %%
print('Alô Mundo!\nUm bom dia!')
# Out:
# Alô Mundo!
# Um bom dia!

# %% [markdown]
# # Exercício 2-1

# %%
print("Lista de compras:\nleite\npão\ncafé")
# Out:
# Lista de compras:
# leite
# pão
# café

# %% [markdown]
# \n é usado para indicar ao interpretador que queremos inserir uma lebra de linha nesta posição dentro de uma literal.

# %%
print(345)
# Out:
# 345

# %%
print(12+5*9)
# Out:
# 57

# %%
print((12+5)*9)
# Out:
# 153

# %%
print('(12+5)*9')
# Out:
# (12+5)*9

# %%
print('12+5*9=',12+5*9)
# Out:
# 12+5*9= 57

# %%
print(12+4,4*5,67-12*2)
# Out:
# 16 20 43

# %% [markdown]
# # Exercício 2-1 pág.18

# %%
print(2+2-2*2+(2-2*(2+2)))
# Out:
# -6

# %%
print(12/5)
# Out:
# 2.4

# %%
print(12.5/4)
# Out:
# 3.125

# %%
print(12,5/4)
# Out:
# 12 1.25

# %%
print(2/3)
# Out:
# 0.6666666666666666

# %% [markdown]
# # Exercício 2-3

# %%
peso=85
altura=1.65
IMC=peso/altura**2
print(IMC)
# Out:
# 31.22130394857668
