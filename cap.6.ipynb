# %%
carga_máxima=500
peso_total=0
while peso_total<=carga_máxima:
    peso_pessoa=int(input('Digite seu peso:'))
    peso_total+=peso_pessoa
print('Peso excedido.')
# Out:
# Digite seu peso: 49
# Digite seu peso: 59
# Digite seu peso: 80
# Digite seu peso: 10
# Digite seu peso: 100
# Digite seu peso: 90
# Digite seu peso: 56
# Digite seu peso: 44
# Digite seu peso: 90
# Peso excedido.
